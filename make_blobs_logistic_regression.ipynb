# %% [markdown]
# <a href="https://colab.research.google.com/github/ibribr/ML/blob/master/make_blobs_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#make_blobs dataset for multiclass classification
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.linear_model import LogisticRegression

# %%
x, y = make_blobs(random_state=42,  centers=4, cluster_std=1.5)

print(y.shape)
print(np.bincount(y))

plt.plot(x[y==0,0], x[y==0,1], 'go', label='class 0')
plt.plot(x[y==1,0], x[y==1,1], 'rd', label='class 1')
plt.plot(x[y==2,0], x[y==2,1], 'b+', label='class 2')
plt.plot(x[y==3,0], x[y==3,1], 'md', label='class 3')


plt.xlabel('x1')
plt.ylabel('x2')
plt.title('3 classes')
plt.legend(loc='upper right')
plt.grid()
plt.show()
# Out:
# (100,)
# [25 25 25 25]

# %%
# build a model
model = LogisticRegression(max_iter = 100, multi_class='ovr')
model.fit(x,y)
y_pred = model.predict(x)

#print(model.score(x, y))

print(model.coef_)
print(model.intercept_)
# Out:
# [[ 0.5132658   1.31981969]
#  [ 1.41539957 -0.31034733]
#  [-0.42695049 -1.01351956]
#  [-1.88794646  0.6639283 ]]
# [ -8.25647913   0.67574857  -3.09522641 -16.47217214]

# %%
# plot decision lines
plt.plot(x[y==0,0], x[y==0,1], 'go', label='class 0')
plt.plot(x[y==1,0], x[y==1,1], 'rd', label='class 1')
plt.plot(x[y==2,0], x[y==2,1], 'b+', label='class 2')
plt.plot(x[y==3,0], x[y==3,1], 'md', label='class 3')

x1 = np.linspace(-10, 10)
color = ['g-','r-','b-', 'm-']

for coef, intercept, color in zip(model.coef_, model.intercept_, color):
  x2 = -(coef[0]*x1+intercept)/coef[1]
  plt.plot(x1, x2, color)

plt.xlabel('x1')
plt.ylabel('x2')
plt.title('3 classes')
plt.legend(loc='upper right')
plt.ylim([-12.0, 12.0])
plt.xlim([-9.0, 7.5])
plt.grid()
plt.show()
